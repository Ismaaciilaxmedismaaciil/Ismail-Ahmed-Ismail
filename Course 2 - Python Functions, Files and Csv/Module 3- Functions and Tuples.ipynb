# %% [markdown]
# # Module 3: Function and Tuples

# %% [markdown]
# ## Function Basics

# %% [markdown]
# ### Function Definition

# %%
# Example: 
def hello():
    '''This function says hello and greets to you'''
    print('Hello')
    print('Glad to see you')


hello()
# Out:
# Hello
# Glad to see you

# %% [markdown]
# ### Function Parameter Passing

# %%
def student(Name, Age):
    '''This function holds student name and Age'''

    print(f'Hello, {Name}.')
    print(f'Your Age must be older than 18, Your Age is {Age}')
    print(f'{Name} Welcome to the Python 3 Programming Bootcam')

student('Ismail Ahmed Ismail', 22)
# Out:
# Hello, Ismail Ahmed Ismail.
# Your Age must be older than 18, Your Age is 22
# Ismail Ahmed Ismail Welcome to the Python 3 Programming Bootcam

# %%
student('Cali Ahmed Hussein', 44)
# Out:
# Hello, Cali Ahmed Hussein.
# Your Age must be older than 18, Your Age is 44
# Cali Ahmed Hussein Welcome to the Python 3 Programming Bootcam

# %%
def hello2(name, num):
    greeting  = f'Hello {name}, '
    print(greeting * num)

hello2('Ismail', 100)
# Out:
# Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hello Ismail, Hell
# ...

# %%
def vote(name, age):
   
    '''This Function checks if person can vote or can't vote'''
    if age > 18:
        print(f'{name}, You can vote. and your age is older than 18, Your age is {age}.')
       
    else:
        print(f"{name}, You can't vote. b/c Your age is younger than 18, Your age is {age}.")
    
    print('Completed...')

 

vote('Ismail Ahmed Ismail', 22)
vote('Cali Ahmed Hussein', 14)
# Out:
# Ismail Ahmed Ismail, You can vote. and your age is older than 18, Your age is 22.
# Completed...
# Cali Ahmed Hussein, You can't vote. b/c Your age is younger than 18, Your age is 14.
# Completed...

# %% [markdown]
# ### Returning Values

# %%
def square_num(num):
    y = num * num

    return y

toSquare = 10
result = square_num(toSquare)

print(f'The result of {toSquare} squared is {result}.')
# Out:
# The result of 10 squared is 100.

# %%
# Opening the csv file then we reading line by line

def reading_file(filename):
    file = open(filename, 'r')

    lines = file.readlines()

    for line in lines:
        print(line.strip())

reading_file('olympics.csv')
# Out:
# Name,Sex,Age,Team,Event,Medal
# A Dijiang,M,24,China,Basketball,NA
# A Lamusi,M,23,China,Judo,NA
# Gunnar Nielsen Aaby,M,24,Denmark,Football,NA
# Edgar Lindenau Aabye,M,34,Denmark/Sweden,Tug-Of-War,Gold
# Christine Jacoba Aaftink,F,21,Netherlands,Speed Skating,NA
# Christine Jacoba Aaftink,F,21,Netherlands,Speed Skating,NA
# Christine Jacoba Aaftink,F,25,Netherlands,Speed Skating,NA
# Christine Jacoba Aaftink,F,25,Netherlands,Speed Skating,NA
# Christine Jacoba Aaftink,F,27,Netherlands,Speed Skating,NA
# Christine Jacoba Aaftink,F,27,Netherlands,Speed Skating,NA
# Per Knut Aaland,M,31,United States,Cross Country Skiing,NA
# Per Knut Aaland,M,31,United States,Cross Country Skiing,NA
# Per Knut Aaland,M,31,United States,Cross Country Skiing,NA
# Per Knut Aaland,M,31,United States,Cross Country Skiing,NA
# Per Knut Aaland,M,33,United States,Cross Country Skiing,NA
# Per Knut Aaland,M,33,United States,Cross Country Skiing,NA
# Per Knut Aaland,M,33,United States,Cross Country Skiing,NA
# ...

# %%
reading_file('log.csv')
# Out:
# time,user,video,playback position,paused,volume
# 1469974424,cheryl,intro.html,5,FALSE,10
# 1469974454,cheryl,intro.html,6,,
# 1469974544,cheryl,intro.html,9,,
# 1469974574,cheryl,intro.html,10,,
# 1469977514,bob,intro.html,1,,
# 1469977544,bob,intro.html,1,,
# 1469977574,bob,intro.html,1,,
# 1469977604,bob,intro.html,1,,
# 1469974604,cheryl,intro.html,11,,
# 1469974694,cheryl,intro.html,14,,
# 1469974724,cheryl,intro.html,15,,
# 1469974454,sue,advanced.html,24,,
# 1469974524,sue,advanced.html,25,,
# 1469974424,sue,advanced.html,23,FALSE,10
# 1469974554,sue,advanced.html,26,,
# 1469974624,sue,advanced.html,27,,
# 1469974654,sue,advanced.html,28,,5
# 1469974724,sue,advanced.html,29,,
# 1469974484,cheryl,intro.html,7,,
# 1469974514,cheryl,intro.html,8,,
# 1469974754,sue,advanced.html,30,,
# 1469974824,sue,advanced.html,31,,
# 1469974854,sue,advanced.html,32,,
# 1469974924,sue,advanced.html,33,,
# 1469977424,bob,intro.html,1,TRUE,10
# 1469977454,bob,intro.html,1,,
# ...

# %%
# Read a text file and count the number of lines, words, and character
def count_text_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        line_count = len(lines)
        word_count = sum(len(line.split()) for line in lines)
        char_count = sum(len(line) for line in lines)
    
    return line_count, word_count, char_count

file_path = 'log.csv'
lines, words, chars = count_text_file(file_path)
print(f'The number of lines is: {lines}, the number of words is: {words}, and the number of characterics is: {chars}')
# Out:
# The number of lines is: 34, the number of words is: 35, and the number of characterics is: 1142

# %% [markdown]
# ### Type Hinting

# %%
def duplicate(msg: str) -> str:
    '''Returns a string containing two copies of msg'''

    return msg + msg 

result = duplicate('Hello')
print(result)
# Out:
# HelloHello

# %%
def square(num: float) -> int:
    '''Returns a squared number'''
    
    y = num * num
    return y

result = square(10.0)

print(result)
# Out:
# 100.0

# %%
def addition(x: int, y: int) -> int:
    '''Returns addition x and y'''
    z = x + y
    return z

x = 10
y = 20

result =addition(x, y)
print(f'The addition of {x} and {y} is: {result}')
# Out:
# The addition of 10 and 20 is: 30

# %%
def greeting(name: str) -> int:
    '''This function describes a greeting'''
    print(f'Hello, {name}')

greeting('Ismail')
# Out:
# Hello, Ismail

# %% [markdown]
# ## Local and Global Variables, and Side Effects

# %% [markdown]
# ### Local and Global Variables

# %%
# Example: Variables and Paramaters are local
def square(x):
    y = x * x
    return y

z = square(10)
# print(y)  # NameError: variable y is not defined. becouse variable y is local variable

# %%
def square(x):

    w = q + 2
    y = x * x

    return w

y = 5
q = 10
z = square(4)
print(z)
# print(y)
# Out:
# 12

# %% [markdown]
# #### Declaring `y` into global variable

# %%
def square(x):
    global y # Decalring y to be global variable

    w = y + 1
    y = x * x

    return y

y = 5
z = square(10)
print(y)
# Out:
# 100

# %%
def badsquare(x):
    y = x ** power
    return y

power = 10
result = badsquare(2)
print(result)
# Out:
# 1024

# %% [markdown]
# ### Function Composition
# #### Function can call other functions

# %%
# Example: Creating a function that squares the numbers
def square(x):
    y = x * x
    return y

# Creating a function thay adds all the squared numbers
def sum_of_squares(x, y, z):
    a = square(x)
    b = square(y)
    c = square(z)

    return a + b + c

a = 10
b = 5
c = 2

result = sum_of_squares(a, b, c)
print(result)
# Out:
# 129

# %%
# Example:
def most_common_letter(s):
    frequancies = count_freqs(s)
    return best_key(frequancies)

def count_freqs(st):
    d = {}
    for c in st:
        if c not in d:
            d[c] = 0
        d[c] += 1

    return d


def best_key(dictionary):
    ks = dictionary.keys()
    best_key_so_far = list(ks)[0]

    for k in ks:
        if dictionary[k] > dictionary[best_key_so_far]:
            best_key_so_far = k
    
    return best_key_so_far


print(most_common_letter('abbbbbbbbbbbccccddddd'))
# Out:
# b

# %%
def double(y):
	y = 2 * y

def changeit(lst):
	lst[0] = 'Michigan'
	lst[1] = 'Wolverines'

y = 5
double(y)
print (y)

mylst = ['our', 'students', 'are', 'awesome']
changeit(mylst)
print(mylst)
# Out:
# 5
# ['Michigan', 'Wolverines', 'are', 'awesome']

# %%
def myfun(lst):
    del lst[0]

mylist = ['a', 'b']
myfun(mylist)
print(mylist)
# Out:
# ['b']

# %% [markdown]
# ## Tuples

# %% [markdown]
# ### Tuples Packing

# %%
julia = ('Julia', 'Roperts', 1969, 'Duplicity', 2009)

# Or Equavalently

julia = 'Julia', 'Roperts', 1969, 'Duplicity', 2009

print(julia[4])
print(julia)
# Out:
# 2009
# ('Julia', 'Roperts', 1969, 'Duplicity', 2009)

# %%
# Assingment 1: 
#  Provided is a list of tuples. Create another list called `t_check` that contains the third element of every tuple.
lst_tups = [('Articuno', 'Moltres', 'Zaptos'), 
            ('Beedrill', 'Metapod', 'Charizard', 'Venasaur', 'Squirtle'),
            ('Oddish', 'Poliwag', 'Diglett', 'Bellsprout'), 
            ('Ponyta', "Farfetch'd", "Tauros", 'Dragonite'), 
            ('Hoothoot', 'Chikorita', 'Lanturn', 'Flaaffy', 'Unown', 'Teddiursa', 'Phanpy'), 
            ('Loudred', 'Volbeat', 'Wailord', 'Seviper', 'Sealeo')]

t_check = []

for third_element in lst_tups:
    t_check.append(third_element[2])

print(t_check)
# Out:
# ['Zaptos', 'Charizard', 'Diglett', 'Tauros', 'Lanturn', 'Wailord']

# %%
# Assingment 2: 
# Below, we have provided a list of tuples. 
# Write a for loop that saves the second element of each tuple into a list called `seconds`.

tups = [('a', 'b', 'c'), 
        (8, 7, 6, 5), 
        ('blue', 'green', 'yellow', 'orange', 'red'), 
        (5.6, 9.99, 2.5, 8.2), 
        ('squirrel', 'chipmunk')]

seconds = []

for second in tups:
    seconds.append(second[1])

print(seconds)
# Out:
# ['b', 7, 'green', 9.99, 'chipmunk']

# %%
def circleInfo(r):
    """ Return (circumference, area) of a circle of radius r """
    c = 2 * 3.14149 * r
    a = 3.14159 * r * r

    return (c, a)

print(circleInfo(10))
print(circleInfo(14))
print(circleInfo(19))
# Out:
# (62.829800000000006, 314.159)
# (87.96172, 615.75164)
# (119.37662, 1134.11399)

# %%
# Define a function called information that takes as input, the variables name, birth_year, fav_color, and hometown. 
# It should return a tuple of these variables in this order.

def information(name, birth_year, fav_color, hometown):
    return (name, birth_year, fav_color, hometown)

print(information('Ismail', 2003, 'Black', 'Garowe'))
# Out:
# ('Ismail', 2003, 'Black', 'Garowe')

# %%
# Define a function called info with the following required parameters: name, age, birth_year, year_in_college, and hometown. 
# The function should return a tuple that contains all the inputted information.

def info(name, age, birth_year, year_in_college, hometown):
    return name, age, birth_year, year_in_college, hometown

print(info('Ismail', 23, 2003, 2022, 'Garowe'))
# Out:
# ('Ismail', 23, 2003, 2022, 'Garowe')

# %% [markdown]
# ### Tuples Unpacking

# %%
# Example 1: Packing
julia = 'Julia', 'Roperts', 1969, 'Duplicity', 2009, 'Actress', 'Atlanta, Gorgie'

# Unpacking
name, surname, birth_year, movie, movie_year, profession, palce_birth = julia


print(name, surname, birth_year, movie, movie_year, profession, palce_birth )
# Out:
# Julia Roperts 1969 Duplicity 2009 Actress Atlanta, Gorgie

# %%
# Another Unpacking Example
a, b, c, d = 1, 2, 3, 4

# %%
def add(x, y):
    return x + y

print(add(3, 4))

z = (5, 4)
print(add(*z)) #This line will cause the value to be unpacked
# print(add(z)) #This line will cause an Error
# Out:
# 7
# 9

# %%
# Example 4:
d = {'k1': 3, 'k2':7, 'k3': 'Some Other value'}

for p in d.items():
    print(f'key: {p[0]}, value: {p[1]}')
# Out:
# key: k1, value: 3
# key: k2, value: 7
# key: k3, value: Some Other value
